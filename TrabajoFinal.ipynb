# %% [markdown]
# <a href="https://colab.research.google.com/github/cabt38/estructura-datos/blob/main/TrabajoFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
nombres = ["Juan", "Carlos", "Andrés", "Camila", "María", "Laura", "Lionel", "Santiago", "Valentina", "Daniela",
           "Diego", "Manuel", "Isabella", "Mateo", "Natalia", "Miguel", "Sara", "Javier", "Alejandra", "Julián",
           "Ana", "Felipe", "Paula", "David", "Adriana", "Jorge", "Gigachad", "Bartolo", "Victoria", "Gabriel"]

# %%
apellidos = ["Gómez", "Rodríguez", "De Luque", "García", "López", "Hernández", "Pérez", "Díaz", "Sánchez", "Torres",
             "Ramírez", "Rojas", "Moreno", "Jiménez", "Castro", "Ortíz", "Messi", "Vargas", "Reyes", "Mendoza"]

# %%
carreras = ["Administración de Empresas", "Ingeniería Industrial", "Contaduría Pública", "Derecho", "Medicina",
            "Ingeniería de Sistemas", "Psicología", "Enfermería", "Comunicación Social y Periodismo", "Economía",
            "Ingeniería Civil", "Arquitectura", "Odontología", "Ingeniería Electrónica", "Ingeniería Mecánica",
            "Pedagogía", "Diseño Gráfico", "Ingeniería Ambiental", "Veterinaria", "Ingeniería Química"]

# %%
actividades_colombia = ["Bailar salsa y vallenato", "Disfrutar de la comida típica", "Fútbol", "Ciclismo", "Café",
                        "Explorar la naturaleza", "Visitar pueblos coloniales",  "Celebrar Carnaval de Barranquilla",
                        "Relajarse en las playas", "Visitar museos y galerías de arte", "Practicar deportes acuáticos",
                        "Escuchar música cumbia", "Compartir tiempo con la familia y amigos",
                        "Participar en eventos religiosos y tradicionales"]

# %%
otras_actividades_colombia = ["Visitar parques nacionales y reservas naturales", "Hacer senderismo en las montañas",
                              "Explorar cuevas y cavernas", "Participar en actividades de ecoturismo",
                              "Asistir a conciertos y eventos musicales",
                              "Practicar deportes extremos como parapente y rafting",
                              "Bañarse en aguas termales",
                              "Participar en actividades de voluntariado comunitario",
                              "Disfrutar de la vida nocturna en bares y discotecas",
                              "Aprender danzas folklóricas colombianas como el currulao"]

# %%
numero_id = []
cantidad_elementos = 100
numero_id = random.sample(range(1, 150), cantidad_elementos)

# %%
def diferentes_datos():
    id_aleatorio = numero_id.pop()
    nombre_aleatorio = random.choice(nombres)
    apellidos_aleatorio = random.choice(apellidos)
    carreras_aleatorio = random.choice(carreras)
    actividades1_aleatorio = random.choice(actividades_colombia)
    actividades2_aleatorio = random.choice(otras_actividades_colombia)
    return id_aleatorio, nombre_aleatorio, apellidos_aleatorio, carreras_aleatorio, actividades1_aleatorio, actividades2_aleatorio

# %%
class Usuario:
    def __init__(self,nombre_aleatorio, apellidos_aleatorio, carreras_aleatorio, actividades1_aleatorio, actividades2_aleatorio, id_aleatorio ):
        self.nombre_aleatorio = nombre_aleatorio
        self.apellidos_aleatorios = apellidos_aleatorio
        self.carreras_aleatorio = carreras_aleatorio
        self.actividades1_aleatorio = actividades1_aleatorio
        self.actividades2_aleatorio = actividades2_aleatorio
        self.id_aleatorio = id_aleatorio

# %%
#Funcion recursiva que nos permite crear los usuarios
def crear_usuarios(n):
    if n == 0:
        return []
    else:
        idUsuario, nombre, apellido, carreras, actividades1, actividades2 = diferentes_datos()

        nuevo_usuario = Usuario(nombre, apellido, carreras, actividades1, actividades2, idUsuario)

        usuarios = crear_usuarios(n - 1)
        usuarios.append(nuevo_usuario)

        return usuarios

# %%
#Ingresar la cantidad de usuarios
cantidad_usuarios = int(input("Ingrese la cantidad de usuarios: "))
lista_usuarios = crear_usuarios(cantidad_usuarios)
# Out:
# Ingrese la cantidad de usuarios: 70

# %%
# Imprimir Usuarios
for usuario in lista_usuarios:
    print(f"Nombre: {usuario.nombre_aleatorio}")
    print(f"Apellidos: {usuario.apellidos_aleatorios}")
    print(f"Carrera: {usuario.carreras_aleatorio}")
    print(f"Actividad 1: {usuario.actividades1_aleatorio}")
    print(f"Actividad 2: {usuario.actividades2_aleatorio}")
    print(f"ID: {usuario.id_aleatorio}")
    print("----------------------------------------------")
# Out:
# Nombre: Miguel
# Apellidos: Gómez
# Carrera: Ingeniería de Sistemas
# Actividad 1: Bailar salsa y vallenato
# Actividad 2: Asistir a conciertos y eventos musicales
# ID: 91
# ----------------------------------------------
# Nombre: Ana
# Apellidos: Rodríguez
# Carrera: Ingeniería Industrial
# Actividad 1: Café
# Actividad 2: Aprender danzas folklóricas colombianas como el currulao
# ID: 50
# ----------------------------------------------
# Nombre: David
# Apellidos: De Luque
# Carrera: Contaduría Pública
# Actividad 1: Participar en eventos religiosos y tradicionales
# Actividad 2: Practicar deportes extremos como parapente y rafting
# ID: 139
# ----------------------------------------------
# Nombre: Isabella
# Apellidos: Jiménez
# Carrera: Enfermería
# Actividad 1: Relajarse en las playas
# Actividad 2: Participar en actividades de ecoturismo
# ID: 118
# ----------------------------------------------
# Nombre: Valentina
# Apellidos: Sánchez
# Carrera: Ingeniería Civil
# Actividad 1: Ciclismo
# Actividad 2: Bañarse en aguas termales
# ID: 25
# ----------------------------------------------
# Nombre: Juan
# Apellidos: Rodríguez
# Carrera: Ingeniería de Sistemas
# Actividad 1: Visitar museos y galerías de arte
# Actividad 2: Participar en actividades de ecoturismo
# ID: 144
# ----------------------------------------------
# Nombre: Laura
# Apellidos: Ramírez
# Carrera: Ingeniería de Sistemas
# Actividad 1: Disfrutar de la comida típica
# Actividad 2: Disfrutar de la vida nocturna en bares y discotecas
# ID: 46
# ----------------------------------------------
# Nombre: Camila
# Apellidos: Reyes
# Carrera: Pedagogía
# Actividad 1: Compartir tiempo con la familia y amigos
# Actividad 2: Bañarse en aguas termales
# ID: 142
# ----------------------------------------------
# Nombre: Miguel
# Apellidos: Moreno
# Carrera: Derecho
# Actividad 1: Fútbol
# Actividad 2: Bañarse en aguas termales
# ID: 4
# ----------------------------------------------
# Nombre: Lionel
# Apellidos: Moreno
# Carrera: Derecho
# Actividad 1: Ciclismo
# Actividad 2: Disfrutar de la vida nocturna en bares y discotecas
# ID: 5
# ----------------------------------------------
# Nombre: Manuel
# Apellidos: Hernández
# Carrera: Veterinaria
# Actividad 1: Compartir tiempo con la familia y amigos
# Actividad 2: Aprender danzas folklóricas colombianas como el currulao
# ID: 10
# ----------------------------------------------
# Nombre: Javier
# Apellidos: De Luque
# Carrera: Economía
# Actividad 1: Ciclismo
# Actividad 2: Visitar parques nacionales y reservas naturales
# ID: 39
# ----------------------------------------------
# Nombre: Camila
# Apellidos: Messi
# Carrera: Administración de Empresas
# Actividad 1: Explorar la naturaleza
# Actividad 2: Practicar deportes extremos como parapente y rafting
# ID: 36
# ----------------------------------------------
# Nombre: Isabella
# Apellidos: García
# Carrera: Veterinaria
# Actividad 1: Escuchar música cumbia
# Actividad 2: Aprender danzas folklóricas colombianas como el currulao
# ID: 134
# ----------------------------------------------
# Nombre: Daniela
# Apellidos: López
# Carrera: Arquitectura
# Actividad 1: Visitar pueblos coloniales
# Actividad 2: Visitar parques nacionales y reservas naturales
# ID: 15
# ----------------------------------------------
# Nombre: Valentina
# Apellidos: Ramírez
# Carrera: Medicina
# Actividad 1: Visitar museos y galerías de arte
# Actividad 2: Explorar cuevas y cavernas
# ID: 21
# ----------------------------------------------
# Nombre: Adriana
# Apellidos: Messi
# Carrera: Diseño Gráfico
# Actividad 1: Café
# Actividad 2: Aprender danzas folklóricas colombianas como el currulao
# ID: 103
# ----------------------------------------------
# Nombre: Gigachad
# Apellidos: Gómez
# Carrera: Ingeniería Industrial
# Actividad 1: Relajarse en las playas
# Actividad 2: Participar en actividades de ecoturismo
# ID: 14
# ----------------------------------------------
# Nombre: Paula
# Apellidos: Rojas
# Carrera: Ingeniería Electrónica
# Actividad 1: Practicar deportes acuáticos
# Actividad 2: Participar en actividades de ecoturismo
# ID: 53
# ----------------------------------------------
# Nombre: Lionel
# Apellidos: Sánchez
# Carrera: Comunicación Social y Periodismo
# Actividad 1: Café
# Actividad 2: Disfrutar de la vida nocturna en bares y discotecas
# ID: 82
# ----------------------------------------------
# Nombre: Juan
# Apellidos: García
# Carrera: Ingeniería Civil
# Actividad 1: Explorar la naturaleza
# Actividad 2: Visitar parques nacionales y reservas naturales
# ID: 38
# ----------------------------------------------
# Nombre: Jorge
# Apellidos: Pérez
# Carrera: Economía
# Actividad 1: Fútbol
# Actividad 2: Participar en actividades de ecoturismo
# ID: 148
# ----------------------------------------------
# Nombre: Alejandra
# Apellidos: Moreno
# Carrera: Medicina
# Actividad 1: Bailar salsa y vallenato
# Actividad 2: Hacer senderismo en las montañas
# ID: 112
# ----------------------------------------------
# Nombre: Santiago
# Apellidos: Jiménez
# Carrera: Ingeniería Civil
# Actividad 1: Ciclismo
# Actividad 2: Hacer senderismo en las montañas
# ID: 11
# ----------------------------------------------
# Nombre: Manuel
# Apellidos: Rojas
# Carrera: Ingeniería Química
# Actividad 1: Bailar salsa y vallenato
# Actividad 2: Hacer senderismo en las montañas
# ID: 116
# ----------------------------------------------
# Nombre: Juan
# Apellidos: Mendoza
# Carrera: Ingeniería Química
# Actividad 1: Disfrutar de la comida típica
# Actividad 2: Hacer senderismo en las montañas
# ID: 19
# ----------------------------------------------
# Nombre: Adriana
# Apellidos: Castro
# Carrera: Ingeniería de Sistemas
# Actividad 1: Practicar deportes acuáticos
# Actividad 2: Aprender danzas folklóricas colombianas como el currulao
# ID: 70
# ----------------------------------------------
# Nombre: Isabella
# Apellidos: Gómez
# Carrera: Contaduría Pública
# Actividad 1: Disfrutar de la comida típica
# Actividad 2: Aprender danzas folklóricas colombianas como el currulao
# ID: 34
# ----------------------------------------------
# Nombre: Javier
# Apellidos: Sánchez
# Carrera: Pedagogía
# Actividad 1: Practicar deportes acuáticos
# Actividad 2: Participar en actividades de ecoturismo
# ID: 80
# ----------------------------------------------
# Nombre: Felipe
# Apellidos: Ramírez
# Carrera: Ingeniería Electrónica
# Actividad 1: Café
# Actividad 2: Participar en actividades de voluntariado comunitario
# ID: 96
# ----------------------------------------------
# Nombre: Natalia
# Apellidos: Rojas
# Carrera: Economía
# Actividad 1: Escuchar música cumbia
# Actividad 2: Visitar parques nacionales y reservas naturales
# ID: 111
# ----------------------------------------------
# Nombre: Mateo
# Apellidos: Mendoza
# Carrera: Ingeniería Ambiental
# Actividad 1: Fútbol
# Actividad 2: Visitar parques nacionales y reservas naturales
# ID: 117
# ----------------------------------------------
# Nombre: Daniela
# Apellidos: Moreno
# Carrera: Medicina
# Actividad 1: Participar en eventos religiosos y tradicionales
# Actividad 2: Aprender danzas folklóricas colombianas como el currulao
# ID: 13
# ----------------------------------------------
# Nombre: Diego
# Apellidos: Castro
# Carrera: Contaduría Pública
# Actividad 1: Bailar salsa y vallenato
# Actividad 2: Disfrutar de la vida nocturna en bares y discotecas
# ID: 45
# ----------------------------------------------
# Nombre: Sara
# Apellidos: Jiménez
# Carrera: Pedagogía
# Actividad 1: Fútbol
# Actividad 2: Practicar deportes extremos como parapente y rafting
# ID: 77
# ----------------------------------------------
# Nombre: Bartolo
# Apellidos: Messi
# Carrera: Ingeniería de Sistemas
# Actividad 1: Practicar deportes acuáticos
# Actividad 2: Participar en actividades de ecoturismo
# ID: 137
# ----------------------------------------------
# Nombre: María
# Apellidos: Gómez
# Carrera: Administración de Empresas
# Actividad 1: Compartir tiempo con la familia y amigos
# Actividad 2: Participar en actividades de ecoturismo
# ID: 33
# ----------------------------------------------
# Nombre: Camila
# Apellidos: Rodríguez
# Carrera: Derecho
# Actividad 1: Compartir tiempo con la familia y amigos
# Actividad 2: Hacer senderismo en las montañas
# ID: 129
# ----------------------------------------------
# Nombre: María
# Apellidos: Torres
# Carrera: Ingeniería Civil
# Actividad 1: Participar en eventos religiosos y tradicionales
# Actividad 2: Practicar deportes extremos como parapente y rafting
# ID: 40
# ----------------------------------------------
# Nombre: Andrés
# Apellidos: Rodríguez
# Carrera: Ingeniería Civil
# Actividad 1: Celebrar Carnaval de Barranquilla
# Actividad 2: Bañarse en aguas termales
# ID: 126
# ----------------------------------------------
# Nombre: Gigachad
# Apellidos: Rojas
# Carrera: Pedagogía
# Actividad 1: Compartir tiempo con la familia y amigos
# Actividad 2: Participar en actividades de ecoturismo
# ID: 9
# ----------------------------------------------
# Nombre: Camila
# Apellidos: Moreno
# Carrera: Psicología
# Actividad 1: Compartir tiempo con la familia y amigos
# Actividad 2: Participar en actividades de ecoturismo
# ID: 131
# ----------------------------------------------
# Nombre: Camila
# Apellidos: López
# Carrera: Ingeniería Civil
# Actividad 1: Café
# Actividad 2: Asistir a conciertos y eventos musicales
# ID: 61
# ----------------------------------------------
# Nombre: Gigachad
# Apellidos: Jiménez
# Carrera: Enfermería
# Actividad 1: Disfrutar de la comida típica
# Actividad 2: Participar en actividades de ecoturismo
# ID: 132
# ----------------------------------------------
# Nombre: Natalia
# Apellidos: López
# Carrera: Administración de Empresas
# Actividad 1: Visitar pueblos coloniales
# Actividad 2: Hacer senderismo en las montañas
# ID: 56
# ----------------------------------------------
# Nombre: David
# Apellidos: Sánchez
# Carrera: Pedagogía
# Actividad 1: Celebrar Carnaval de Barranquilla
# Actividad 2: Bañarse en aguas termales
# ID: 37
# ----------------------------------------------
# Nombre: Alejandra
# Apellidos: Ortíz
# Carrera: Veterinaria
# Actividad 1: Café
# Actividad 2: Bañarse en aguas termales
# ID: 41
# ----------------------------------------------
# Nombre: Paula
# Apellidos: García
# Carrera: Medicina
# Actividad 1: Relajarse en las playas
# Actividad 2: Participar en actividades de voluntariado comunitario
# ID: 140
# ----------------------------------------------
# Nombre: Valentina
# Apellidos: Díaz
# Carrera: Administración de Empresas
# Actividad 1: Compartir tiempo con la familia y amigos
# Actividad 2: Hacer senderismo en las montañas
# ID: 6
# ----------------------------------------------
# Nombre: Camila
# Apellidos: Rodríguez
# Carrera: Derecho
# Actividad 1: Fútbol
# Actividad 2: Aprender danzas folklóricas colombianas como el currulao
# ID: 128
# ----------------------------------------------
# Nombre: Daniela
# Apellidos: Messi
# Carrera: Ingeniería de Sistemas
# Actividad 1: Celebrar Carnaval de Barranquilla
# Actividad 2: Bañarse en aguas termales
# ID: 114
# ----------------------------------------------
# Nombre: Alejandra
# Apellidos: Díaz
# Carrera: Diseño Gráfico
# Actividad 1: Explorar la naturaleza
# Actividad 2: Bañarse en aguas termales
# ID: 98
# ----------------------------------------------
# Nombre: Santiago
# Apellidos: Castro
# Carrera: Ingeniería Industrial
# Actividad 1: Participar en eventos religiosos y tradicionales
# Actividad 2: Participar en actividades de ecoturismo
# ID: 121
# ----------------------------------------------
# Nombre: Julián
# Apellidos: Torres
# Carrera: Ingeniería Ambiental
# Actividad 1: Compartir tiempo con la familia y amigos
# Actividad 2: Explorar cuevas y cavernas
# ID: 3
# ----------------------------------------------
# Nombre: Julián
# Apellidos: Moreno
# Carrera: Arquitectura
# Actividad 1: Fútbol
# Actividad 2: Aprender danzas folklóricas colombianas como el currulao
# ID: 90
# ----------------------------------------------
# Nombre: Adriana
# Apellidos: López
# Carrera: Administración de Empresas
# Actividad 1: Disfrutar de la comida típica
# Actividad 2: Hacer senderismo en las montañas
# ID: 135
# ----------------------------------------------
# Nombre: Julián
# Apellidos: Pérez
# Carrera: Psicología
# Actividad 1: Fútbol
# Actividad 2: Participar en actividades de voluntariado comunitario
# ID: 58
# ----------------------------------------------
# Nombre: Santiago
# Apellidos: Castro
# Carrera: Pedagogía
# Actividad 1: Café
# Actividad 2: Practicar deportes extremos como parapente y rafting
# ID: 24
# ----------------------------------------------
# Nombre: Lionel
# Apellidos: Gómez
# Carrera: Administración de Empresas
# Actividad 1: Escuchar música cumbia
# Actividad 2: Disfrutar de la vida nocturna en bares y discotecas
# ID: 145
# ----------------------------------------------
# Nombre: Mateo
# Apellidos: Vargas
# Carrera: Ingeniería Química
# Actividad 1: Practicar deportes acuáticos
# Actividad 2: Participar en actividades de ecoturismo
# ID: 35
# ----------------------------------------------
# Nombre: Paula
# Apellidos: Jiménez
# Carrera: Administración de Empresas
# Actividad 1: Explorar la naturaleza
# Actividad 2: Participar en actividades de ecoturismo
# ID: 147
# ----------------------------------------------
# Nombre: Carlos
# Apellidos: Vargas
# Carrera: Medicina
# Actividad 1: Practicar deportes acuáticos
# Actividad 2: Practicar deportes extremos como parapente y rafting
# ID: 94
# ----------------------------------------------
# Nombre: Miguel
# Apellidos: Díaz
# Carrera: Ingeniería Industrial
# Actividad 1: Participar en eventos religiosos y tradicionales
# Actividad 2: Disfrutar de la vida nocturna en bares y discotecas
# ID: 66
# ----------------------------------------------
# Nombre: David
# Apellidos: Sánchez
# Carrera: Enfermería
# Actividad 1: Visitar pueblos coloniales
# Actividad 2: Practicar deportes extremos como parapente y rafting
# ID: 22
# ----------------------------------------------
# Nombre: Gabriel
# Apellidos: Castro
# Carrera: Ingeniería Industrial
# Actividad 1: Relajarse en las playas
# Actividad 2: Practicar deportes extremos como parapente y rafting
# ID: 130
# ----------------------------------------------
# Nombre: Javier
# Apellidos: Rojas
# Carrera: Psicología
# Actividad 1: Participar en eventos religiosos y tradicionales
# Actividad 2: Visitar parques nacionales y reservas naturales
# ID: 127
# ----------------------------------------------
# Nombre: Bartolo
# Apellidos: López
# Carrera: Ingeniería Electrónica
# Actividad 1: Visitar museos y galerías de arte
# Actividad 2: Bañarse en aguas termales
# ID: 120
# ----------------------------------------------
# Nombre: David
# Apellidos: Díaz
# Carrera: Psicología
# Actividad 1: Visitar pueblos coloniales
# Actividad 2: Aprender danzas folklóricas colombianas como el currulao
# ID: 28
# ----------------------------------------------
# Nombre: Camila
# Apellidos: Rojas
# Carrera: Ingeniería Ambiental
# Actividad 1: Relajarse en las playas
# Actividad 2: Practicar deportes extremos como parapente y rafting
# ID: 136
# ----------------------------------------------
# Nombre: David
# Apellidos: Torres
# Carrera: Medicina
# Actividad 1: Fútbol
# Actividad 2: Explorar cuevas y cavernas
# ID: 105
# ----------------------------------------------

# %%
#Funcion que nos permite borrar datos que se encuentran almacenados en lista_usuarios
def eliminar_usuario_por_id(lista_usuarios):
    id_a_eliminar = int(input("Ingrese el ID del usuario que desea eliminar: "))
    usuarios_eliminados = [usuario for usuario in lista_usuarios if usuario.id_aleatorio == id_a_eliminar]

    if usuarios_eliminados:
        lista_usuarios[:] = [usuario for usuario in lista_usuarios if usuario.id_aleatorio != id_a_eliminar]
        print(f"Se eliminaron {len(usuarios_eliminados)} usuarios con el numero del ID {id_a_eliminar}.")
    else:
        print(f"No se encontraron usuarios con el ID {id_a_eliminar}.")

eliminar_usuario_por_id(lista_usuarios)
# Out:
# Ingrese el ID del usuario que desea eliminar: 142
# Se eliminaron 1 usuarios con el numero del ID 142.

# %%
#Funcion que nos permite crear nuevos datos que se almaceran en lista_usuarios
def agregar_usuarios_extra(lista_usuarios):
    cantidad_a_agregar = int(input("Ingrese la cantidad de usuarios que desea agregar: "))

    for _ in range(cantidad_a_agregar):
        id_usuario, nombre, apellidos, carrera, actividad1, actividad2 = diferentes_datos()
        nuevo_usuario = Usuario(nombre, apellidos, carrera, actividad1, actividad2, id_usuario)
        lista_usuarios.append(nuevo_usuario)

agregar_usuarios_extra(lista_usuarios)
# Out:
# Ingrese la cantidad de usuarios que desea agregar: 5

# %%
# Imprimir Usuarios
for usuario in lista_usuarios:
    print(f"Nombre: {usuario.nombre_aleatorio}")
    print(f"Apellidos: {usuario.apellidos_aleatorios}")
    print(f"Carrera: {usuario.carreras_aleatorio}")
    print(f"Actividad 1: {usuario.actividades1_aleatorio}")
    print(f"Actividad 2: {usuario.actividades2_aleatorio}")
    print(f"ID: {usuario.id_aleatorio}")
    print("----------------------------------------------")
# Out:
# Nombre: Miguel
# Apellidos: Gómez
# Carrera: Ingeniería de Sistemas
# Actividad 1: Bailar salsa y vallenato
# Actividad 2: Asistir a conciertos y eventos musicales
# ID: 91
# ----------------------------------------------
# Nombre: Ana
# Apellidos: Rodríguez
# Carrera: Ingeniería Industrial
# Actividad 1: Café
# Actividad 2: Aprender danzas folklóricas colombianas como el currulao
# ID: 50
# ----------------------------------------------
# Nombre: David
# Apellidos: De Luque
# Carrera: Contaduría Pública
# Actividad 1: Participar en eventos religiosos y tradicionales
# Actividad 2: Practicar deportes extremos como parapente y rafting
# ID: 139
# ----------------------------------------------
# Nombre: Isabella
# Apellidos: Jiménez
# Carrera: Enfermería
# Actividad 1: Relajarse en las playas
# Actividad 2: Participar en actividades de ecoturismo
# ID: 118
# ----------------------------------------------
# Nombre: Valentina
# Apellidos: Sánchez
# Carrera: Ingeniería Civil
# Actividad 1: Ciclismo
# Actividad 2: Bañarse en aguas termales
# ID: 25
# ----------------------------------------------
# Nombre: Juan
# Apellidos: Rodríguez
# Carrera: Ingeniería de Sistemas
# Actividad 1: Visitar museos y galerías de arte
# Actividad 2: Participar en actividades de ecoturismo
# ID: 144
# ----------------------------------------------
# Nombre: Laura
# Apellidos: Ramírez
# Carrera: Ingeniería de Sistemas
# Actividad 1: Disfrutar de la comida típica
# Actividad 2: Disfrutar de la vida nocturna en bares y discotecas
# ID: 46
# ----------------------------------------------
# Nombre: Miguel
# Apellidos: Moreno
# Carrera: Derecho
# Actividad 1: Fútbol
# Actividad 2: Bañarse en aguas termales
# ID: 4
# ----------------------------------------------
# Nombre: Lionel
# Apellidos: Moreno
# Carrera: Derecho
# Actividad 1: Ciclismo
# Actividad 2: Disfrutar de la vida nocturna en bares y discotecas
# ID: 5
# ----------------------------------------------
# Nombre: Manuel
# Apellidos: Hernández
# Carrera: Veterinaria
# Actividad 1: Compartir tiempo con la familia y amigos
# Actividad 2: Aprender danzas folklóricas colombianas como el currulao
# ID: 10
# ----------------------------------------------
# Nombre: Javier
# Apellidos: De Luque
# Carrera: Economía
# Actividad 1: Ciclismo
# Actividad 2: Visitar parques nacionales y reservas naturales
# ID: 39
# ----------------------------------------------
# Nombre: Camila
# Apellidos: Messi
# Carrera: Administración de Empresas
# Actividad 1: Explorar la naturaleza
# Actividad 2: Practicar deportes extremos como parapente y rafting
# ID: 36
# ----------------------------------------------
# Nombre: Isabella
# Apellidos: García
# Carrera: Veterinaria
# Actividad 1: Escuchar música cumbia
# Actividad 2: Aprender danzas folklóricas colombianas como el currulao
# ID: 134
# ----------------------------------------------
# Nombre: Daniela
# Apellidos: López
# Carrera: Arquitectura
# Actividad 1: Visitar pueblos coloniales
# Actividad 2: Visitar parques nacionales y reservas naturales
# ID: 15
# ----------------------------------------------
# Nombre: Valentina
# Apellidos: Ramírez
# Carrera: Medicina
# Actividad 1: Visitar museos y galerías de arte
# Actividad 2: Explorar cuevas y cavernas
# ID: 21
# ----------------------------------------------
# Nombre: Adriana
# Apellidos: Messi
# Carrera: Diseño Gráfico
# Actividad 1: Café
# Actividad 2: Aprender danzas folklóricas colombianas como el currulao
# ID: 103
# ----------------------------------------------
# Nombre: Gigachad
# Apellidos: Gómez
# Carrera: Ingeniería Industrial
# Actividad 1: Relajarse en las playas
# Actividad 2: Participar en actividades de ecoturismo
# ID: 14
# ----------------------------------------------
# Nombre: Paula
# Apellidos: Rojas
# Carrera: Ingeniería Electrónica
# Actividad 1: Practicar deportes acuáticos
# Actividad 2: Participar en actividades de ecoturismo
# ID: 53
# ----------------------------------------------
# Nombre: Lionel
# Apellidos: Sánchez
# Carrera: Comunicación Social y Periodismo
# Actividad 1: Café
# Actividad 2: Disfrutar de la vida nocturna en bares y discotecas
# ID: 82
# ----------------------------------------------
# Nombre: Juan
# Apellidos: García
# Carrera: Ingeniería Civil
# Actividad 1: Explorar la naturaleza
# Actividad 2: Visitar parques nacionales y reservas naturales
# ID: 38
# ----------------------------------------------
# Nombre: Jorge
# Apellidos: Pérez
# Carrera: Economía
# Actividad 1: Fútbol
# Actividad 2: Participar en actividades de ecoturismo
# ID: 148
# ----------------------------------------------
# Nombre: Alejandra
# Apellidos: Moreno
# Carrera: Medicina
# Actividad 1: Bailar salsa y vallenato
# Actividad 2: Hacer senderismo en las montañas
# ID: 112
# ----------------------------------------------
# Nombre: Santiago
# Apellidos: Jiménez
# Carrera: Ingeniería Civil
# Actividad 1: Ciclismo
# Actividad 2: Hacer senderismo en las montañas
# ID: 11
# ----------------------------------------------
# Nombre: Manuel
# Apellidos: Rojas
# Carrera: Ingeniería Química
# Actividad 1: Bailar salsa y vallenato
# Actividad 2: Hacer senderismo en las montañas
# ID: 116
# ----------------------------------------------
# Nombre: Juan
# Apellidos: Mendoza
# Carrera: Ingeniería Química
# Actividad 1: Disfrutar de la comida típica
# Actividad 2: Hacer senderismo en las montañas
# ID: 19
# ----------------------------------------------
# Nombre: Adriana
# Apellidos: Castro
# Carrera: Ingeniería de Sistemas
# Actividad 1: Practicar deportes acuáticos
# Actividad 2: Aprender danzas folklóricas colombianas como el currulao
# ID: 70
# ----------------------------------------------
# Nombre: Isabella
# Apellidos: Gómez
# Carrera: Contaduría Pública
# Actividad 1: Disfrutar de la comida típica
# Actividad 2: Aprender danzas folklóricas colombianas como el currulao
# ID: 34
# ----------------------------------------------
# Nombre: Javier
# Apellidos: Sánchez
# Carrera: Pedagogía
# Actividad 1: Practicar deportes acuáticos
# Actividad 2: Participar en actividades de ecoturismo
# ID: 80
# ----------------------------------------------
# Nombre: Felipe
# Apellidos: Ramírez
# Carrera: Ingeniería Electrónica
# Actividad 1: Café
# Actividad 2: Participar en actividades de voluntariado comunitario
# ID: 96
# ----------------------------------------------
# Nombre: Natalia
# Apellidos: Rojas
# Carrera: Economía
# Actividad 1: Escuchar música cumbia
# Actividad 2: Visitar parques nacionales y reservas naturales
# ID: 111
# ----------------------------------------------
# Nombre: Mateo
# Apellidos: Mendoza
# Carrera: Ingeniería Ambiental
# Actividad 1: Fútbol
# Actividad 2: Visitar parques nacionales y reservas naturales
# ID: 117
# ----------------------------------------------
# Nombre: Daniela
# Apellidos: Moreno
# Carrera: Medicina
# Actividad 1: Participar en eventos religiosos y tradicionales
# Actividad 2: Aprender danzas folklóricas colombianas como el currulao
# ID: 13
# ----------------------------------------------
# Nombre: Diego
# Apellidos: Castro
# Carrera: Contaduría Pública
# Actividad 1: Bailar salsa y vallenato
# Actividad 2: Disfrutar de la vida nocturna en bares y discotecas
# ID: 45
# ----------------------------------------------
# Nombre: Sara
# Apellidos: Jiménez
# Carrera: Pedagogía
# Actividad 1: Fútbol
# Actividad 2: Practicar deportes extremos como parapente y rafting
# ID: 77
# ----------------------------------------------
# Nombre: Bartolo
# Apellidos: Messi
# Carrera: Ingeniería de Sistemas
# Actividad 1: Practicar deportes acuáticos
# Actividad 2: Participar en actividades de ecoturismo
# ID: 137
# ----------------------------------------------
# Nombre: María
# Apellidos: Gómez
# Carrera: Administración de Empresas
# Actividad 1: Compartir tiempo con la familia y amigos
# Actividad 2: Participar en actividades de ecoturismo
# ID: 33
# ----------------------------------------------
# Nombre: Camila
# Apellidos: Rodríguez
# Carrera: Derecho
# Actividad 1: Compartir tiempo con la familia y amigos
# Actividad 2: Hacer senderismo en las montañas
# ID: 129
# ----------------------------------------------
# Nombre: María
# Apellidos: Torres
# Carrera: Ingeniería Civil
# Actividad 1: Participar en eventos religiosos y tradicionales
# Actividad 2: Practicar deportes extremos como parapente y rafting
# ID: 40
# ----------------------------------------------
# Nombre: Andrés
# Apellidos: Rodríguez
# Carrera: Ingeniería Civil
# Actividad 1: Celebrar Carnaval de Barranquilla
# Actividad 2: Bañarse en aguas termales
# ID: 126
# ----------------------------------------------
# Nombre: Gigachad
# Apellidos: Rojas
# Carrera: Pedagogía
# Actividad 1: Compartir tiempo con la familia y amigos
# Actividad 2: Participar en actividades de ecoturismo
# ID: 9
# ----------------------------------------------
# Nombre: Camila
# Apellidos: Moreno
# Carrera: Psicología
# Actividad 1: Compartir tiempo con la familia y amigos
# Actividad 2: Participar en actividades de ecoturismo
# ID: 131
# ----------------------------------------------
# Nombre: Camila
# Apellidos: López
# Carrera: Ingeniería Civil
# Actividad 1: Café
# Actividad 2: Asistir a conciertos y eventos musicales
# ID: 61
# ----------------------------------------------
# Nombre: Gigachad
# Apellidos: Jiménez
# Carrera: Enfermería
# Actividad 1: Disfrutar de la comida típica
# Actividad 2: Participar en actividades de ecoturismo
# ID: 132
# ----------------------------------------------
# Nombre: Natalia
# Apellidos: López
# Carrera: Administración de Empresas
# Actividad 1: Visitar pueblos coloniales
# Actividad 2: Hacer senderismo en las montañas
# ID: 56
# ----------------------------------------------
# Nombre: David
# Apellidos: Sánchez
# Carrera: Pedagogía
# Actividad 1: Celebrar Carnaval de Barranquilla
# Actividad 2: Bañarse en aguas termales
# ID: 37
# ----------------------------------------------
# Nombre: Alejandra
# Apellidos: Ortíz
# Carrera: Veterinaria
# Actividad 1: Café
# Actividad 2: Bañarse en aguas termales
# ID: 41
# ----------------------------------------------
# Nombre: Paula
# Apellidos: García
# Carrera: Medicina
# Actividad 1: Relajarse en las playas
# Actividad 2: Participar en actividades de voluntariado comunitario
# ID: 140
# ----------------------------------------------
# Nombre: Valentina
# Apellidos: Díaz
# Carrera: Administración de Empresas
# Actividad 1: Compartir tiempo con la familia y amigos
# Actividad 2: Hacer senderismo en las montañas
# ID: 6
# ----------------------------------------------
# Nombre: Camila
# Apellidos: Rodríguez
# Carrera: Derecho
# Actividad 1: Fútbol
# Actividad 2: Aprender danzas folklóricas colombianas como el currulao
# ID: 128
# ----------------------------------------------
# Nombre: Daniela
# Apellidos: Messi
# Carrera: Ingeniería de Sistemas
# Actividad 1: Celebrar Carnaval de Barranquilla
# Actividad 2: Bañarse en aguas termales
# ID: 114
# ----------------------------------------------
# Nombre: Alejandra
# Apellidos: Díaz
# Carrera: Diseño Gráfico
# Actividad 1: Explorar la naturaleza
# Actividad 2: Bañarse en aguas termales
# ID: 98
# ----------------------------------------------
# Nombre: Santiago
# Apellidos: Castro
# Carrera: Ingeniería Industrial
# Actividad 1: Participar en eventos religiosos y tradicionales
# Actividad 2: Participar en actividades de ecoturismo
# ID: 121
# ----------------------------------------------
# Nombre: Julián
# Apellidos: Torres
# Carrera: Ingeniería Ambiental
# Actividad 1: Compartir tiempo con la familia y amigos
# Actividad 2: Explorar cuevas y cavernas
# ID: 3
# ----------------------------------------------
# Nombre: Julián
# Apellidos: Moreno
# Carrera: Arquitectura
# Actividad 1: Fútbol
# Actividad 2: Aprender danzas folklóricas colombianas como el currulao
# ID: 90
# ----------------------------------------------
# Nombre: Adriana
# Apellidos: López
# Carrera: Administración de Empresas
# Actividad 1: Disfrutar de la comida típica
# Actividad 2: Hacer senderismo en las montañas
# ID: 135
# ----------------------------------------------
# Nombre: Julián
# Apellidos: Pérez
# Carrera: Psicología
# Actividad 1: Fútbol
# Actividad 2: Participar en actividades de voluntariado comunitario
# ID: 58
# ----------------------------------------------
# Nombre: Santiago
# Apellidos: Castro
# Carrera: Pedagogía
# Actividad 1: Café
# Actividad 2: Practicar deportes extremos como parapente y rafting
# ID: 24
# ----------------------------------------------
# Nombre: Lionel
# Apellidos: Gómez
# Carrera: Administración de Empresas
# Actividad 1: Escuchar música cumbia
# Actividad 2: Disfrutar de la vida nocturna en bares y discotecas
# ID: 145
# ----------------------------------------------
# Nombre: Mateo
# Apellidos: Vargas
# Carrera: Ingeniería Química
# Actividad 1: Practicar deportes acuáticos
# Actividad 2: Participar en actividades de ecoturismo
# ID: 35
# ----------------------------------------------
# Nombre: Paula
# Apellidos: Jiménez
# Carrera: Administración de Empresas
# Actividad 1: Explorar la naturaleza
# Actividad 2: Participar en actividades de ecoturismo
# ID: 147
# ----------------------------------------------
# Nombre: Carlos
# Apellidos: Vargas
# Carrera: Medicina
# Actividad 1: Practicar deportes acuáticos
# Actividad 2: Practicar deportes extremos como parapente y rafting
# ID: 94
# ----------------------------------------------
# Nombre: Miguel
# Apellidos: Díaz
# Carrera: Ingeniería Industrial
# Actividad 1: Participar en eventos religiosos y tradicionales
# Actividad 2: Disfrutar de la vida nocturna en bares y discotecas
# ID: 66
# ----------------------------------------------
# Nombre: David
# Apellidos: Sánchez
# Carrera: Enfermería
# Actividad 1: Visitar pueblos coloniales
# Actividad 2: Practicar deportes extremos como parapente y rafting
# ID: 22
# ----------------------------------------------
# Nombre: Gabriel
# Apellidos: Castro
# Carrera: Ingeniería Industrial
# Actividad 1: Relajarse en las playas
# Actividad 2: Practicar deportes extremos como parapente y rafting
# ID: 130
# ----------------------------------------------
# Nombre: Javier
# Apellidos: Rojas
# Carrera: Psicología
# Actividad 1: Participar en eventos religiosos y tradicionales
# Actividad 2: Visitar parques nacionales y reservas naturales
# ID: 127
# ----------------------------------------------
# Nombre: Bartolo
# Apellidos: López
# Carrera: Ingeniería Electrónica
# Actividad 1: Visitar museos y galerías de arte
# Actividad 2: Bañarse en aguas termales
# ID: 120
# ----------------------------------------------
# Nombre: David
# Apellidos: Díaz
# Carrera: Psicología
# Actividad 1: Visitar pueblos coloniales
# Actividad 2: Aprender danzas folklóricas colombianas como el currulao
# ID: 28
# ----------------------------------------------
# Nombre: Camila
# Apellidos: Rojas
# Carrera: Ingeniería Ambiental
# Actividad 1: Relajarse en las playas
# Actividad 2: Practicar deportes extremos como parapente y rafting
# ID: 136
# ----------------------------------------------
# Nombre: David
# Apellidos: Torres
# Carrera: Medicina
# Actividad 1: Fútbol
# Actividad 2: Explorar cuevas y cavernas
# ID: 105
# ----------------------------------------------
# Nombre: Santiago
# Apellidos: López
# Carrera: Enfermería
# Actividad 1: Café
# Actividad 2: Asistir a conciertos y eventos musicales
# ID: 49
# ----------------------------------------------
# Nombre: Alejandra
# Apellidos: Moreno
# Carrera: Ingeniería Química
# Actividad 1: Escuchar música cumbia
# Actividad 2: Aprender danzas folklóricas colombianas como el currulao
# ID: 99
# ----------------------------------------------
# Nombre: Natalia
# Apellidos: Ortíz
# Carrera: Ingeniería Industrial
# Actividad 1: Compartir tiempo con la familia y amigos
# Actividad 2: Practicar deportes extremos como parapente y rafting
# ID: 7
# ----------------------------------------------
# Nombre: Juan
# Apellidos: Rojas
# Carrera: Derecho
# Actividad 1: Escuchar música cumbia
# Actividad 2: Hacer senderismo en las montañas
# ID: 95
# ----------------------------------------------
# Nombre: Gigachad
# Apellidos: Jiménez
# Carrera: Contaduría Pública
# Actividad 1: Celebrar Carnaval de Barranquilla
# Actividad 2: Explorar cuevas y cavernas
# ID: 69
# ----------------------------------------------

# %%
#NetworkX es una biblioteca de Python para el estudio de grafos y análisis de redes
import networkx as nx
import matplotlib.pyplot as plt

# %%
# Crear un grafo dirigido
G = nx.DiGraph()

# %%
#Funcion que recorre lista_usuarios y crea nodos en un grafo, donde cada nodo está representado por un ID
for usuario in lista_usuarios:
  #Nombre del grafo (G)
    G.add_node(usuario.id_aleatorio, nombre=usuario.nombre_aleatorio)

# %%
#Funcion la cual crea las conexiones entre los nodos en el grafo (G), donde si los usuarios tienen actividades o carreras aleatorias coincidentes se conectan.
for usuario in lista_usuarios:
    for otro_usuario in lista_usuarios:
        if usuario != otro_usuario:
            if usuario.actividades1_aleatorio == otro_usuario.actividades1_aleatorio or \
               usuario.carreras_aleatorio == otro_usuario.carreras_aleatorio:
                G.add_edge(usuario.id_aleatorio, otro_usuario.id_aleatorio)

# %%
#usuario.actividades2_aleatorio == otro_usuario.actividades2_aleatorio or \

# %%
# Dibuja el grafo con un largo de arista mayor (incrementando scale)
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=230, node_color='skyblue', width=0.4)
plt.show()

# %%
#Librería de Python especializada en la manipulación y el análisis de datos.
import pandas as pd

# %%
#Lista que contienen las etiquetas 'Actividades 1', 'Actividades 2', 'Carreras' que nos permite almacenar los usuarios dentro de esta.
motivos = ['Actividades 1', 'Actividades 2', 'Carreras']

# %%
'''
Esta funcion recorre los motivos predefinidos en la lista motivos y para cada motivo, examina la lista de usuarios para encontrar
conexiones entre ellos según el motivo específico
'''

for motivo in motivos:
    conexiones = []
    for usuario in lista_usuarios:
        for otro_usuario in lista_usuarios:
            if usuario != otro_usuario:
                if motivo == 'Actividades 1' and usuario.actividades1_aleatorio == otro_usuario.actividades1_aleatorio:
                    conexiones.append([usuario.id_aleatorio, otro_usuario.id_aleatorio, 'Actividades 1'])
                elif motivo == 'Actividades 2' and usuario.actividades2_aleatorio == otro_usuario.actividades2_aleatorio:
                    conexiones.append([usuario.id_aleatorio, otro_usuario.id_aleatorio, 'Actividades 2'])
                elif motivo == 'Carreras' and usuario.carreras_aleatorio == otro_usuario.carreras_aleatorio:
                    conexiones.append([usuario.id_aleatorio, otro_usuario.id_aleatorio, 'Carreras'])

# Crear DataFrame de Pandas para mostrar las conexiones con sus motivos
    if conexiones:
        df = pd.DataFrame(conexiones, columns=['ID Perfil 1', 'ID Perfil 2', 'Motivo'])
        print(f"DataFrame para {motivo}:")
        with pd.option_context('display.max_rows', 100):
            print(df)
            print("\n")
# Out:
# DataFrame para Actividades 1:
#      ID Perfil 1  ID Perfil 2         Motivo
# 0             91          112  Actividades 1
# 1             91          116  Actividades 1
# 2             91           45  Actividades 1
# 3             50          103  Actividades 1
# 4             50           82  Actividades 1
# ..           ...          ...            ...
# 349           95          145  Actividades 1
# 350           95           99  Actividades 1
# 351           69          126  Actividades 1
# 352           69           37  Actividades 1
# 353           69          114  Actividades 1
#
# [354 rows x 3 columns]
#
#
# DataFrame para Actividades 2:
#      ID Perfil 1  ID Perfil 2         Motivo
# 0             91           61  Actividades 2
# 1             91           49  Actividades 2
# 2             50           10  Actividades 2
# 3             50          134  Actividades 2
# 4             50          103  Actividades 2
# ..           ...          ...            ...
# 589           95            6  Actividades 2
# 590           95          135  Actividades 2
# 591           69           21  Actividades 2
# 592           69            3  Actividades 2
# 593           69          105  Actividades 2
#
# [594 rows x 3 columns]
#
#
# DataFrame para Carreras:
#      ID Perfil 1  ID Perfil 2    Motivo
# 0             91          144  Carreras
# 1             91           46  Carreras
# 2             91           70  Carreras
# 3             91          137  Carreras
# 4             91          114  Carreras
# ..           ...          ...       ...
# 273           95          129  Carreras
# 274           95          128  Carreras
# 275           69          139  Carreras
# 276           69           34  Carreras
# 277           69           45  Carreras
#
# [278 rows x 3 columns]
